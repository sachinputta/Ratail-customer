# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('Customer_Buying_Patterns.csv')

# %%
df.head()
# Out:
#    CustomerMobileNo       BillNo    BillDate  \
# 0        6263895415  18122200036  22-12-2018
# 1        6263895415  18122200036  22-12-2018
# 2        6263895415  18122200036  22-12-2018
# 3        6281123186  19021600010  16-02-2019
# 4        6300037707  18112600011  26-11-2018
#
#                                         CategoryName  \
# 0                    BISCUITS / CAKE / CHIPS / SNAKS
# 1                    BISCUITS / CAKE / CHIPS / SNAKS
# 2  COOL DRINKS / FRUIT JUICES / MILK SHAKES  / SA...
# 3                                     ROOM FRESHENER
# 4                    BISCUITS / CAKE / CHIPS / SNAKS
#
#                             ProductName  Qty    MRP  Discount  Amount
# 0  BRITANNIA CAKE PINEAPPLE PLUNGE 15RS    2   15.0      0.00   30.00
# 1          LAYS SPANISH TOMATO TANGO 10    1   10.0      0.05    9.95
# 2                                 STING    2   30.0      3.00   57.00
# 3            GLADE WILD LAVENDER 300 ML    1  150.0      3.00  147.00
# ...

# %%
data=df.iloc[:,2:8]

# %%
data.head()
# Out:
#      BillDate                                       CategoryName  \
# 0  22-12-2018                    BISCUITS / CAKE / CHIPS / SNAKS
# 1  22-12-2018                    BISCUITS / CAKE / CHIPS / SNAKS
# 2  22-12-2018  COOL DRINKS / FRUIT JUICES / MILK SHAKES  / SA...
# 3  16-02-2019                                     ROOM FRESHENER
# 4  26-11-2018                    BISCUITS / CAKE / CHIPS / SNAKS
#
#                             ProductName  Qty    MRP  Discount
# 0  BRITANNIA CAKE PINEAPPLE PLUNGE 15RS    2   15.0      0.00
# 1          LAYS SPANISH TOMATO TANGO 10    1   10.0      0.05
# 2                                 STING    2   30.0      3.00
# 3            GLADE WILD LAVENDER 300 ML    1  150.0      3.00
# 4                            GOOD DAY 5    1    5.0      0.20

# %%
df.dtypes
# Out:
# CustomerMobileNo      int64
# BillNo                int64
# BillDate             object
# CategoryName         object
# ProductName          object
# Qty                   int64
# MRP                 float64
# Discount            float64
# Amount              float64
# dtype: object

# %%
df['ProductName'] = df['ProductName'].astype("category")

# %%
df['ProductName'] = df['ProductName'].cat.codes

# %%
df['ProductName'] = df['ProductName'].astype(float)

# %%
df.dtypes
# Out:
# CustomerMobileNo      int64
# BillNo                int64
# BillDate             object
# CategoryName         object
# ProductName         float64
# Qty                   int64
# MRP                 float64
# Discount            float64
# Amount              float64
# dtype: object

# %%
df.head()
# Out:
#    CustomerMobileNo       BillNo    BillDate  \
# 0        6263895415  18122200036  22-12-2018
# 1        6263895415  18122200036  22-12-2018
# 2        6263895415  18122200036  22-12-2018
# 3        6281123186  19021600010  16-02-2019
# 4        6300037707  18112600011  26-11-2018
#
#                                         CategoryName  ProductName  Qty    MRP  \
# 0                    BISCUITS / CAKE / CHIPS / SNAKS        237.0    2   15.0
# 1                    BISCUITS / CAKE / CHIPS / SNAKS        917.0    1   10.0
# 2  COOL DRINKS / FRUIT JUICES / MILK SHAKES  / SA...       1514.0    2   30.0
# 3                                     ROOM FRESHENER        657.0    1  150.0
# 4                    BISCUITS / CAKE / CHIPS / SNAKS        674.0    1    5.0
#
#    Discount  Amount
# 0      0.00   30.00
# 1      0.05    9.95
# 2      3.00   57.00
# 3      3.00  147.00
# 4      0.20    4.80

# %%
df['MRP'] = df['MRP'].apply(lambda v: (v - df['MRP'].min()) / (df['MRP'].max() - df['MRP'].min() ))

# %%
df.head()
# Out:
#    CustomerMobileNo       BillNo    BillDate  \
# 0        6263895415  18122200036  22-12-2018
# 1        6263895415  18122200036  22-12-2018
# 2        6263895415  18122200036  22-12-2018
# 3        6281123186  19021600010  16-02-2019
# 4        6300037707  18112600011  26-11-2018
#
#                                         CategoryName  ProductName  Qty  \
# 0                    BISCUITS / CAKE / CHIPS / SNAKS        237.0    2
# 1                    BISCUITS / CAKE / CHIPS / SNAKS        917.0    1
# 2  COOL DRINKS / FRUIT JUICES / MILK SHAKES  / SA...       1514.0    2
# 3                                     ROOM FRESHENER        657.0    1
# 4                    BISCUITS / CAKE / CHIPS / SNAKS        674.0    1
#
#         MRP  Discount  Amount
# 0  0.009375      0.00   30.00
# 1  0.006250      0.05    9.95
# 2  0.018750      3.00   57.00
# 3  0.093750      3.00  147.00
# 4  0.003125      0.20    4.80

# %%
df['Discount'] = df['Discount'].apply(lambda v: (v - df['Discount'].min()) / (df['Discount'].max() - df['Discount'].min() ))

# %%
df.head()
# Out:
#    CustomerMobileNo       BillNo    BillDate  \
# 0        6263895415  18122200036  22-12-2018
# 1        6263895415  18122200036  22-12-2018
# 2        6263895415  18122200036  22-12-2018
# 3        6281123186  19021600010  16-02-2019
# 4        6300037707  18112600011  26-11-2018
#
#                                         CategoryName  ProductName  Qty  \
# 0                    BISCUITS / CAKE / CHIPS / SNAKS        237.0    2
# 1                    BISCUITS / CAKE / CHIPS / SNAKS        917.0    1
# 2  COOL DRINKS / FRUIT JUICES / MILK SHAKES  / SA...       1514.0    2
# 3                                     ROOM FRESHENER        657.0    1
# 4                    BISCUITS / CAKE / CHIPS / SNAKS        674.0    1
#
#         MRP  Discount  Amount
# 0  0.009375  0.000000   30.00
# 1  0.006250  0.000154    9.95
# 2  0.018750  0.009231   57.00
# 3  0.093750  0.009231  147.00
# 4  0.003125  0.000615    4.80

# %%
df['Amount'] = df['Amount'].apply(lambda v: (v - df['Amount'].min()) / (df['Amount'].max() - df['Amount'].min() ))

# %%
df.head(10)
# Out:
#    CustomerMobileNo       BillNo    BillDate  \
# 0        6263895415  18122200036  22-12-2018
# 1        6263895415  18122200036  22-12-2018
# 2        6263895415  18122200036  22-12-2018
# 3        6281123186  19021600010  16-02-2019
# 4        6300037707  18112600011  26-11-2018
# 5        6300037707  18112600011  26-11-2018
# 6        6300037707  18112600011  26-11-2018
# 7        6300037707  18112600011  26-11-2018
# 8        6300037707  18112700028  27-11-2018
# 9        6300037707  18112700028  27-11-2018
#
#                                         CategoryName  ProductName  Qty  \
# 0                    BISCUITS / CAKE / CHIPS / SNAKS        237.0    2
# 1                    BISCUITS / CAKE / CHIPS / SNAKS        917.0    1
# 2  COOL DRINKS / FRUIT JUICES / MILK SHAKES  / SA...       1514.0    2
# 3                                     ROOM FRESHENER        657.0    1
# 4                    BISCUITS / CAKE / CHIPS / SNAKS        674.0    1
# ...

# %%
df['BillNo'] = df['BillNo'].astype("category")

# %%
df['BillNo'] = df['BillNo'].cat.codes

# %%
df['BillNo'] = df['BillNo'].astype(int)

# %%
df.dtypes
# Out:
# CustomerMobileNo      int64
# BillNo                int64
# BillDate             object
# CategoryName         object
# ProductName         float64
# Qty                   int64
# MRP                 float64
# Discount            float64
# Amount              float64
# dtype: object

# %%
df.head()
# Out:
#    CustomerMobileNo  BillNo    BillDate  \
# 0        6263895415     906  22-12-2018
# 1        6263895415     906  22-12-2018
# 2        6263895415     906  22-12-2018
# 3        6281123186    2090  16-02-2019
# 4        6300037707     390  26-11-2018
#
#                                         CategoryName  ProductName  Qty  \
# 0                    BISCUITS / CAKE / CHIPS / SNAKS        237.0    2
# 1                    BISCUITS / CAKE / CHIPS / SNAKS        917.0    1
# 2  COOL DRINKS / FRUIT JUICES / MILK SHAKES  / SA...       1514.0    2
# 3                                     ROOM FRESHENER        657.0    1
# 4                    BISCUITS / CAKE / CHIPS / SNAKS        674.0    1
#
#         MRP  Discount    Amount
# 0  0.009375  0.000000  0.023529
# 1  0.006250  0.000154  0.007804
# 2  0.018750  0.009231  0.044706
# 3  0.093750  0.009231  0.115294
# 4  0.003125  0.000615  0.003765

# %%
df['ProductName'] = df['ProductName'].apply(lambda v: (v - df['ProductName'].min()) / (df['ProductName'].max() - df['ProductName'].min() ))

# %%
df.head()
# Out:
#    CustomerMobileNo  BillNo    BillDate  \
# 0        6263895415     906  22-12-2018
# 1        6263895415     906  22-12-2018
# 2        6263895415     906  22-12-2018
# 3        6281123186    2090  16-02-2019
# 4        6300037707     390  26-11-2018
#
#                                         CategoryName  ProductName  Qty  \
# 0                    BISCUITS / CAKE / CHIPS / SNAKS     0.136207    2
# 1                    BISCUITS / CAKE / CHIPS / SNAKS     0.527011    1
# 2  COOL DRINKS / FRUIT JUICES / MILK SHAKES  / SA...     0.870115    2
# 3                                     ROOM FRESHENER     0.377586    1
# 4                    BISCUITS / CAKE / CHIPS / SNAKS     0.387356    1
#
#         MRP  Discount    Amount
# 0  0.009375  0.000000  0.023529
# 1  0.006250  0.000154  0.007804
# 2  0.018750  0.009231  0.044706
# 3  0.093750  0.009231  0.115294
# 4  0.003125  0.000615  0.003765

# %%
df['Qty'] = df['Qty'].astype(float)

# %%
df.dtypes
# Out:
# CustomerMobileNo      int64
# BillNo                int64
# BillDate             object
# CategoryName         object
# ProductName         float64
# Qty                 float64
# MRP                 float64
# Discount            float64
# Amount              float64
# dtype: object

# %%
df['Qty'] = df['Qty'].apply(lambda v: (v - df['Qty'].min()) / (df['Qty'].max() - df['Qty'].min() ))

# %%
df.head(10)
# Out:
#    CustomerMobileNo  BillNo    BillDate  \
# 0        6263895415     906  22-12-2018
# 1        6263895415     906  22-12-2018
# 2        6263895415     906  22-12-2018
# 3        6281123186    2090  16-02-2019
# 4        6300037707     390  26-11-2018
# 5        6300037707     390  26-11-2018
# 6        6300037707     390  26-11-2018
# 7        6300037707     390  26-11-2018
# 8        6300037707     418  27-11-2018
# 9        6300037707     418  27-11-2018
#
#                                         CategoryName  ProductName       Qty  \
# 0                    BISCUITS / CAKE / CHIPS / SNAKS     0.136207  0.008403
# 1                    BISCUITS / CAKE / CHIPS / SNAKS     0.527011  0.000000
# 2  COOL DRINKS / FRUIT JUICES / MILK SHAKES  / SA...     0.870115  0.008403
# 3                                     ROOM FRESHENER     0.377586  0.000000
# 4                    BISCUITS / CAKE / CHIPS / SNAKS     0.387356  0.000000
# ...

# %%
df['BillDate'] = df['BillDate'].astype("category")

# %%
df['BillDate'] = df['BillDate'].cat.codes

# %%
df['BillDate'] = df['BillDate'].astype(int)

# %%
df.dtypes
# Out:
# CustomerMobileNo      int64
# BillNo                int64
# BillDate              int64
# CategoryName         object
# ProductName         float64
# Qty                 float64
# MRP                 float64
# Discount            float64
# Amount              float64
# dtype: object

# %%
df.head()
# Out:
#    CustomerMobileNo  BillNo  BillDate  \
# 0        6263895415     906        96
# 1        6263895415     906        96
# 2        6263895415     906        96
# 3        6281123186    2090        66
# 4        6300037707     390       111
#
#                                         CategoryName  ProductName       Qty  \
# 0                    BISCUITS / CAKE / CHIPS / SNAKS     0.136207  0.008403
# 1                    BISCUITS / CAKE / CHIPS / SNAKS     0.527011  0.000000
# 2  COOL DRINKS / FRUIT JUICES / MILK SHAKES  / SA...     0.870115  0.008403
# 3                                     ROOM FRESHENER     0.377586  0.000000
# 4                    BISCUITS / CAKE / CHIPS / SNAKS     0.387356  0.000000
#
#         MRP  Discount    Amount
# 0  0.009375  0.000000  0.023529
# 1  0.006250  0.000154  0.007804
# 2  0.018750  0.009231  0.044706
# 3  0.093750  0.009231  0.115294
# 4  0.003125  0.000615  0.003765

# %%
df.describe()
# Out:
#        CustomerMobileNo       BillNo     BillDate  ProductName          Qty  \
# count      7.775000e+03  7775.000000  7775.000000  7775.000000  7775.000000
# mean       9.153738e+09  1376.386109    63.651061     0.471017     0.004548
# std        8.084457e+08   869.706983    35.767933     0.291381     0.021988
# min        6.263895e+09     0.000000     0.000000     0.000000     0.000000
# 25%        8.985205e+09   612.000000    34.000000     0.181034     0.000000
# 50%        9.491551e+09  1333.000000    63.000000     0.481609     0.000000
# 75%        9.581325e+09  2121.000000    96.000000     0.719253     0.000000
# max        9.985676e+09  2929.000000   128.000000     1.000000     1.000000
#
#                MRP     Discount       Amount
# count  7775.000000  7775.000000  7775.000000
# mean      0.030087     0.009887     0.041290
# std       0.048848     0.034540     0.062744
# min       0.000000     0.000000     0.000000
# 25%       0.006250     0.000000     0.007843
# ...

# %%
df.to_csv("prepocessing.csv", index=False)

# %%
new_df = pd.read_csv('prepocessing.csv')

# %%
new_df.head()
# Out:
#    CustomerMobileNo  BillNo  BillDate  \
# 0        6263895415     906        96
# 1        6263895415     906        96
# 2        6263895415     906        96
# 3        6281123186    2090        66
# 4        6300037707     390       111
#
#                                         CategoryName  ProductName       Qty  \
# 0                    BISCUITS / CAKE / CHIPS / SNAKS     0.136207  0.008403
# 1                    BISCUITS / CAKE / CHIPS / SNAKS     0.527011  0.000000
# 2  COOL DRINKS / FRUIT JUICES / MILK SHAKES  / SA...     0.870115  0.008403
# 3                                     ROOM FRESHENER     0.377586  0.000000
# 4                    BISCUITS / CAKE / CHIPS / SNAKS     0.387356  0.000000
#
#         MRP  Discount    Amount
# 0  0.009375  0.000000  0.023529
# 1  0.006250  0.000154  0.007804
# 2  0.018750  0.009231  0.044706
# 3  0.093750  0.009231  0.115294
# 4  0.003125  0.000615  0.003765

# %%
new_df.corr()
# Out:
#                   CustomerMobileNo    BillNo  BillDate  ProductName       Qty  \
# CustomerMobileNo          1.000000 -0.080283 -0.033455     0.017989 -0.002799
# BillNo                   -0.080283  1.000000 -0.083798    -0.033418 -0.015727
# BillDate                 -0.033455 -0.083798  1.000000    -0.012510 -0.019916
# ProductName               0.017989 -0.033418 -0.012510     1.000000 -0.032472
# Qty                      -0.002799 -0.015727 -0.019916    -0.032472  1.000000
# MRP                       0.017436 -0.029074 -0.022082     0.037570 -0.089323
# Discount                 -0.000890  0.018418 -0.004007     0.038259  0.007544
# Amount                    0.024755 -0.041377 -0.035392     0.035229  0.069786
#
#                        MRP  Discount    Amount
# CustomerMobileNo  0.017436 -0.000890  0.024755
# BillNo           -0.029074  0.018418 -0.041377
# BillDate         -0.022082 -0.004007 -0.035392
# ProductName       0.037570  0.038259  0.035229
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.matshow(new_df.corr(), cmap ='summer')
plt.colorbar()

plt.xticks(list(range(len(new_df.columns))),new_df.columns,rotation='vertical')
plt.yticks(list(range(len(new_df.columns))),new_df.columns,rotation='horizontal')
plt.show()

# %%
new_df.corr()['Qty'].sort_values(ascending = False)
# Out:
# Qty                 1.000000
# Amount              0.069786
# Discount            0.007544
# CustomerMobileNo   -0.002799
# BillNo             -0.015727
# BillDate           -0.019916
# ProductName        -0.032472
# MRP                -0.089323
# Name: Qty, dtype: float64

# %%
new_df.corr()['Discount'].sort_values(ascending = False)
# Out:
# Discount            1.000000
# MRP                 0.642488
# Amount              0.627456
# ProductName         0.038259
# BillNo              0.018418
# Qty                 0.007544
# CustomerMobileNo   -0.000890
# BillDate           -0.004007
# Name: Discount, dtype: float64

# %%
new_df.corr()['Amount'].sort_values(ascending = False)
# Out:
# Amount              1.000000
# MRP                 0.930541
# Discount            0.627456
# Qty                 0.069786
# ProductName         0.035229
# CustomerMobileNo    0.024755
# BillDate           -0.035392
# BillNo             -0.041377
# Name: Amount, dtype: float64

# %%
new_df.plot.box()
plt.xticks(list(range(len(new_df.columns))),new_df.columns,rotation='vertical')
# Out:
# ([<matplotlib.axis.XTick at 0x11988af90>,
# ...
#  <a list of 9 Text xticklabel objects>)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pylab
import pandas as pd
from scipy import stats
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn import preprocessing
from sklearn.decomposition import PCA

# %%
from numpy import mean
from numpy import std
from numpy import var

# %%
fields=['Amount','Qty','Discount','CategoryName','CategoryName','ProductName']

df= pd.read_csv('Customer_Buying_Patterns.csv',encoding='cp1252',usecols=fields)

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

# %%
print( IQR)
# Out:
# Qty          0.00
# Discount     2.00
# Amount      51.25
# dtype: float64

# %%
df.dtypes
# Out:
# CategoryName     object
# ProductName      object
# Qty               int64
# Discount        float64
# Amount          float64
# dtype: object

# %%
mu, sigma = 0.5, 0.1

print('mean ', mean(df['Amount']))
print('std ', std(df['Amount']))
print('var ', var(df['Amount']))
print ('skd ',df['Qty'].skew())
# Out:
# ('mean ', 52.644531189710605)
# ('std ', 79.9938255096861)
# ('var ', 6399.012119674107)
# ('skd ', 22.84559669552909)

# %%
count, bins, ignored = plt.hist(df['Qty'], 20, normed=True)

plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
    np.exp( - (bins - mu)*2 / (2 * sigma*2) ),       linewidth=3, color='y')
plt.show()




sns.pairplot(df, kind="scatter")
plt.show()
